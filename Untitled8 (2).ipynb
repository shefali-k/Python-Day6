# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import csv
url ='C:/Users/User/Desktop/BlackFriday.csv'
df = pd.read_csv(url)

print(df)
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0       1000001  P00069042      F   0-17          10             A
# 1       1000001  P00248942      F   0-17          10             A
# 2       1000001  P00087842      F   0-17          10             A
# 3       1000001  P00085442      F   0-17          10             A
# 4       1000002  P00285442      M    55+          16             C
# 5       1000003  P00193542      M  26-35          15             A
# 6       1000004  P00184942      M  46-50           7             B
# 7       1000004  P00346142      M  46-50           7             B
# 8       1000004   P0097242      M  46-50           7             B
# 9       1000005  P00274942      M  26-35          20             A
# 10      1000005  P00251242      M  26-35          20             A
# 11      1000005  P00014542      M  26-35          20             A
# 12      1000005  P00031342      M  26-35          20             A
# ...

# %%
#1)Get the columns or features of  of the Dataset
df.columns
# Out:
# Index(['User_ID', 'Product_ID', 'Gender', 'Age', 'Occupation', 'City_Category',
#        'Stay_In_Current_City_Years', 'Marital_Status', 'Product_Category_1',
#        'Product_Category_2', 'Product_Category_3', 'Purchase'],
#       dtype='object')

# %%
#2)How many observations are there in the dataset
df.index
# Out:
# RangeIndex(start=0, stop=537577, step=1)

# %%
#3)What are the missing values ? How many for each category?
print(df.isnull().values.any()) #For checking if null value exists
print(df.isnull().sum().sum()) #For calculating the total number of missing values
df.isnull().sum() #Category wise missing values
# Out:
# True
# 540285
# User_ID                            0
# Product_ID                         0
# Gender                             0
# Age                                0
# Occupation                         0
# City_Category                      0
# Stay_In_Current_City_Years         0
# Marital_Status                     0
# Product_Category_1                 0
# Product_Category_2            166986
# Product_Category_3            373299
# Purchase                           0
# dtype: int64

# %%
#4)How many unique values for UserId and Product Id
print('Unique values for UserID',len(df.User_ID.unique()))
print('Unique values for ProductID',len(df.Product_ID.unique()))
# Out:
# Unique values for UserID 5891
# Unique values for ProductID 3623

# %%
#5)How many males and females in the data set?
print("Females are: ",df.isin(['F']).sum().sum())
print("Males are: ",df.isin(['M']).sum().sum())
# Out:
# Females are:  132197
# Males are:  405380

# %%
#6)Print a frequency chart for the age groups
#df['Age'].value_counts().plot('bar')
df["Age"].value_counts()
# Out:
# 26-35    214690
# 36-45    107499
# 18-25     97634
# 46-50     44526
# 51-55     37618
# 55+       20903
# 0-17      14707
# Name: Age, dtype: int64

# %%
#7)What is the distribution of marital status of people?
#df['Marital_Status'].value_counts().plot('bar')
df['Marital_Status'].value_counts()
# Out:
# 0    317817
# 1    219760
# Name: Marital_Status, dtype: int64

# %%
#8)Create 3 files for each of the city category
df[df.City_Category=='A']
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0       1000001  P00069042      F   0-17          10             A
# 1       1000001  P00248942      F   0-17          10             A
# 2       1000001  P00087842      F   0-17          10             A
# 3       1000001  P00085442      F   0-17          10             A
# 5       1000003  P00193542      M  26-35          15             A
# 9       1000005  P00274942      M  26-35          20             A
# 10      1000005  P00251242      M  26-35          20             A
# 11      1000005  P00014542      M  26-35          20             A
# 12      1000005  P00031342      M  26-35          20             A
# 13      1000005  P00145042      M  26-35          20             A
# 14      1000006  P00231342      F  51-55           9             A
# 15      1000006  P00190242      F  51-55           9             A
# 16      1000006   P0096642      F  51-55           9             A
# ...

# %%
df[df.City_Category=='B']
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 6       1000004  P00184942      M  46-50           7             B
# 7       1000004  P00346142      M  46-50           7             B
# 8       1000004   P0097242      M  46-50           7             B
# 18      1000007  P00036842      M  36-45           1             B
# 29      1000010  P00085942      F  36-45           1             B
# 30      1000010  P00118742      F  36-45           1             B
# 31      1000010  P00297942      F  36-45           1             B
# 32      1000010  P00266842      F  36-45           1             B
# 33      1000010  P00058342      F  36-45           1             B
# 34      1000010  P00032442      F  36-45           1             B
# 35      1000010  P00105942      F  36-45           1             B
# 36      1000010  P00182642      F  36-45           1             B
# 37      1000010  P00186942      F  36-45           1             B
# ...

# %%
df[df.City_Category=='C']
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 4       1000002  P00285442      M    55+          16             C
# 19      1000008  P00249542      M  26-35          12             C
# 20      1000008  P00220442      M  26-35          12             C
# 21      1000008  P00156442      M  26-35          12             C
# 22      1000008  P00213742      M  26-35          12             C
# 23      1000008  P00214442      M  26-35          12             C
# 24      1000008  P00303442      M  26-35          12             C
# 25      1000009  P00135742      M  26-35          17             C
# 26      1000009  P00039942      M  26-35          17             C
# 27      1000009  P00161442      M  26-35          17             C
# 28      1000009  P00078742      M  26-35          17             C
# 47      1000011  P00192642      F  26-35           1             C
# 48      1000011  P00110842      F  26-35           1             C
# ...

# %%
#9)Draw a frequency chart for the occupation
#df['Occupation'].value_counts().plot('bar')
df['Occupation'].value_counts()
# Out:
# 4     70862
# 0     68120
# 7     57806
# 1     45971
# 17    39090
# 20    32910
# 12    30423
# 14    26712
# 2     25845
# 16    24790
# 6     19822
# 3     17366
# 10    12623
# 5     11985
# 15    11812
# 11    11338
# 19     8352
# 13     7548
# 18     6525
# 9      6153
# 8      1524
# Name: Occupation, dtype: int64

# %%
#10)What is the purchase value for males and females
print('Purchase value for male: ',df[(df.Gender=='M')].Purchase.sum())
print('Purchase value for female: ',df[(df.Gender=='F')].Purchase.sum())
# Out:
# Purchase value for male:  3853044357
# Purchase value for female:  1164624021

# %%
#11)Add an additional column for country (Country is US)
df['Country']=pd.Series(["US"]*len(df.index))
df.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# 3                          2               0                  12
# 4                         4+               0                   8
#
#    Product_Category_2  Product_Category_3  Purchase Country
# 0                 NaN                 NaN      8370      US
# 1                 6.0                14.0     15200      US
# ...

# %%
#12)Show the head of the data frame
df.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# 3                          2               0                  12
# 4                         4+               0                   8
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 NaN                 NaN      8370
# 1                 6.0                14.0     15200
# ...

# %%
#13)Show the last part of the dataframe
df.tail()
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 537572  1004737  P00193542      M  36-45          16             C
# 537573  1004737  P00111142      M  36-45          16             C
# 537574  1004737  P00345942      M  36-45          16             C
# 537575  1004737  P00285842      M  36-45          16             C
# 537576  1004737  P00118242      M  36-45          16             C
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 537572                          1               0                   1
# 537573                          1               0                   1
# 537574                          1               0                   8
# 537575                          1               0                   5
# 537576                          1               0                   5
#
#         Product_Category_2  Product_Category_3  Purchase
# 537572                 2.0                 NaN     11664
# ...

# %%
#14)Get the details of  user 1000001
df[df.User_ID==1000001]
# Out:
#         User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0       1000001  P00069042      F  0-17          10             A
# 1       1000001  P00248942      F  0-17          10             A
# 2       1000001  P00087842      F  0-17          10             A
# 3       1000001  P00085442      F  0-17          10             A
# 39180   1000001  P00085942      F  0-17          10             A
# 78144   1000001  P00102642      F  0-17          10             A
# 78145   1000001  P00110842      F  0-17          10             A
# 78146   1000001  P00004842      F  0-17          10             A
# 116848  1000001  P00117942      F  0-17          10             A
# 116849  1000001  P00258742      F  0-17          10             A
# 116850  1000001  P00142242      F  0-17          10             A
# 116851  1000001  P00000142      F  0-17          10             A
# 155570  1000001  P00297042      F  0-17          10             A
# ...

# %%
#15)Get the details of the 50th observation
df.iloc[49]
# Out:
# User_ID                         1000011
# Product_ID                    P00189642
# Gender                                F
# Age                               26-35
# Occupation                            1
# City_Category                         C
# Stay_In_Current_City_Years            1
# Marital_Status                        0
# Product_Category_1                    8
# Product_Category_2                   13
# Product_Category_3                  NaN
# Purchase                           8027
# Country                              US
# Name: 49, dtype: object

# %%
#16)Create a small data frame with only user_id, age and purchase
df.loc[:,['User_ID','Age','Purchase']]
# Out:
#         User_ID    Age  Purchase
# 0       1000001   0-17      8370
# 1       1000001   0-17     15200
# 2       1000001   0-17      1422
# 3       1000001   0-17      1057
# 4       1000002    55+      7969
# 5       1000003  26-35     15227
# 6       1000004  46-50     19215
# 7       1000004  46-50     15854
# 8       1000004  46-50     15686
# 9       1000005  26-35      7871
# 10      1000005  26-35      5254
# 11      1000005  26-35      3957
# 12      1000005  26-35      6073
# 13      1000005  26-35     15665
# 14      1000006  51-55      5378
# 15      1000006  51-55      2079
# 16      1000006  51-55     13055
# 17      1000006  51-55      8851
# 18      1000007  36-45     11788
# 19      1000008  26-35     19614
# 20      1000008  26-35      8584
# 21      1000008  26-35      9872
# 22      1000008  26-35      9743
# 23      1000008  26-35      5982
# 24      1000008  26-35     11927
# 25      1000009  26-35     16662
# 26      1000009  26-35      5887
# ...

# %%
#17)Print first 10 rows of the data frame
df[0:11]
# Out:
#     User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0   1000001  P00069042      F   0-17          10             A
# 1   1000001  P00248942      F   0-17          10             A
# 2   1000001  P00087842      F   0-17          10             A
# 3   1000001  P00085442      F   0-17          10             A
# 4   1000002  P00285442      M    55+          16             C
# 5   1000003  P00193542      M  26-35          15             A
# 6   1000004  P00184942      M  46-50           7             B
# 7   1000004  P00346142      M  46-50           7             B
# 8   1000004   P0097242      M  46-50           7             B
# 9   1000005  P00274942      M  26-35          20             A
# 10  1000005  P00251242      M  26-35          20             A
#
#    Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                           2               0                   3
# 1                           2               0                   1
# ...

# %%
#18)Sort the data frame based on purchase.
df.sort_values(by='Purchase')
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 377309  1004048  P00041442      F  36-45           1             B
# 411541  1003391  P00041442      M  18-25           4             A
# 27602   1004227  P00171342      M  26-35          19             A
# 403039  1001968  P00102142      M  26-35          11             B
# 400498  1001630  P00135542      M  46-50          17             C
# 266446  1005039  P00032642      F  36-45           4             B
# 233619  1006025  P00041442      F  26-35           1             B
# 5466    1000889  P00041442      M  46-50          20             A
# 172340  1002660  P00087142      M    55+          17             C
# 6609    1001066  P00200442      M  46-50          12             C
# 514048  1001198  P00212042      M   0-17          10             C
# 345191  1005120  P00066742      M  51-55           7             A
# 454981  1004028  P00041442      M  26-35           4             A
# ...

# %%
#19)Show the summary stastics related to each of the age groups
df['Age'].describe()
# Out:
# count     537577
# unique         7
# top        26-35
# freq      214690
# Name: Age, dtype: object

# %%
#20)List all purchases lower than 100 and bigger than 10000
df.query('Purchase < 100' and 'Purchase > 10000')
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 1       1000001  P00248942      F   0-17          10             A
# 5       1000003  P00193542      M  26-35          15             A
# 6       1000004  P00184942      M  46-50           7             B
# 7       1000004  P00346142      M  46-50           7             B
# 8       1000004   P0097242      M  46-50           7             B
# 13      1000005  P00145042      M  26-35          20             A
# 16      1000006   P0096642      F  51-55           9             A
# 18      1000007  P00036842      M  36-45           1             B
# 19      1000008  P00249542      M  26-35          12             C
# 24      1000008  P00303442      M  26-35          12             C
# 25      1000009  P00135742      M  26-35          17             C
# 29      1000010  P00085942      F  36-45           1             B
# 33      1000010  P00058342      F  36-45           1             B
# ...
